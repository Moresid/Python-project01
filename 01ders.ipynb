# %%
sayi1= int (input("karenin kenarı: "))

cevre= sayi1*4
alan=sayi1*sayi1

print(f"Alanı: {alan} \nÇevresi: {cevre}")
# Out:
# karenin kenarı: 7
# Alanı: 49
# Çevresi: 28

# %%
taban= int (input("üçgenin tabanı: "))
yükseklik= int (input("üçgenin yüksekliği: "))

alan= taban*yükseklik /2 
print(f" üçgenin alanı= {alan}")
# Out:
# üçgenin tabanı: 7
# üçgenin yüksekliği: 9
#  üçgenin alanı= 31.5
